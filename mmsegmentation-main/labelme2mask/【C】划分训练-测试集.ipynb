# %% [markdown]
# # 划分训练-测试集
#
# 张子豪 2023-2-22 6-9

# %% [markdown]
# ## 导入工具包

# %%
import os
import shutil
import random

from tqdm import tqdm

# %% [markdown]
# ## 指定数据集路径

# %%
import os
# 假设 mmsegmentation 的绝对路径是 /project/mmsegmentation
mmsegmentation_path = "E:/bishe_custom_data/mmsegmentation-main"
# 切换到 mmsegmentation 文件夹
os.chdir(mmsegmentation_path)
# 验证当前工作目录
print("当前工作目录:", os.getcwd())  # 输出: /project/mmsegmentation
# Out:
# 当前工作目录: E:\bishe_custom_data\mmsegmentation-main

# %%
Dataset_Path = 'data/mmseg_custom_dataset'

# %% [markdown]
# ## 查看数据集目录结构

# %%
import seedir as sd
sd.seedir(Dataset_Path, style='emoji', depthlimit=1)
# Out:
# 📁 mmseg_custom_dataset/
# ├─📁 ann_dir/
# └─📁 img_dir/

# %% [markdown]
# ## 创建文件夹

# %%
os.chdir(Dataset_Path)
os.mkdir('train')
os.mkdir('val')

# %%
len(os.listdir('img_dir'))
# Out:
# 240

# %%
len(os.listdir('ann_dir'))
# Out:
# 240

# %% [markdown]
# ## 删除系统自动生成的多余文件

# %% [markdown]
# ### 查看待删除的多余文件

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'

# %% [markdown]
# ### 删除多余文件

# %%
# !for i in `find . -iname '__MACOSX'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.DS_Store'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.ipynb_checkpoints'`; do rm -rf $i;done

# %% [markdown]
# ### 验证多余文件已删除

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'

# %% [markdown]
# ## 在图像文件夹中，划分训练集和测试集

# %%
test_frac = 0.2  # 测试集比例
random.seed(123) # 随机数种子，便于复现

# %%
folder = 'img_dir'

# %%
img_paths = os.listdir(folder)
random.shuffle(img_paths) # 随机打乱

val_number = int(len(img_paths) * test_frac) # 测试集文件个数
train_files = img_paths[val_number:]         # 训练集文件名列表
val_files = img_paths[:val_number]           # 测试集文件名列表

print('数据集文件总数', len(img_paths))
print('训练集文件个数', len(train_files))
print('测试集文件个数', len(val_files))
# Out:
# 数据集文件总数 240
# 训练集文件个数 192
# 测试集文件个数 48

# %% [markdown]
# ## 将训练集图像移动至`train`目录

# %%
for each in tqdm(train_files):
    src_path = os.path.join(folder, each)
    dst_path = os.path.join('train', each)
    shutil.move(src_path, dst_path)
# Out:
# 100%|██████████| 192/192 [00:00<00:00, 1878.80it/s]

# %% [markdown]
# ## 将测试集图像移动至`val`目录

# %%
for each in tqdm(val_files):
    src_path = os.path.join(folder, each)
    dst_path = os.path.join('val', each)
    shutil.move(src_path, dst_path)
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 2596.29it/s]

# %%
len(os.listdir('train')) + len(os.listdir('val'))
# Out:
# 240

# %% [markdown]
# ## 将`train`和`val`剪切至`img_dir`

# %%
shutil.move('train', 'img_dir/train')
shutil.move('val', 'img_dir/val')
# Out:
# 'img_dir/val'

# %% [markdown]
# ## 在标注文件夹中，划分训练集和测试集

# %%
folder = 'ann_dir'

# %%
os.mkdir('train')
os.mkdir('val')

# %% [markdown]
# ## 将训练集标注移动至`train`目录

# %%
for each in tqdm(train_files):
    src_path = os.path.join(folder, each.split('.')[0]+'.png')
    dst_path = os.path.join('train', each.split('.')[0]+'.png')
    shutil.move(src_path, dst_path)
# Out:
# 100%|██████████| 192/192 [00:00<00:00, 2252.45it/s]

# %% [markdown]
# ## 将测试集标注移动至`val`目录

# %%
for each in tqdm(val_files):
    src_path = os.path.join(folder, each.split('.')[0]+'.png')
    dst_path = os.path.join('val', each.split('.')[0]+'.png')
    shutil.move(src_path, dst_path)
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 1623.76it/s]

# %%
len(os.listdir('train')) + len(os.listdir('val'))
# Out:
# 240

# %% [markdown]
# ## 将`train`和`val`剪切至`ann_dir`

# %%
shutil.move('train', 'ann_dir/train')
shutil.move('val', 'ann_dir/val')
# Out:
# 'ann_dir/val'

# %% [markdown]
# ## 删除系统自动生成的多余文件

# %%
os.chdir('../')

# %% [markdown]
# ### 查看待删除的多余文件

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'

# %% [markdown]
# ### 删除多余文件

# %%
# !for i in `find . -iname '__MACOSX'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.DS_Store'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.ipynb_checkpoints'`; do rm -rf $i;done

# %% [markdown]
# ### 验证多余文件已删除

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'

# %% [markdown]
# ## 得到划分好训练集测试集的完整语义分割数据集
